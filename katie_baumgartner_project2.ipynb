# %% [markdown]
# # Project 2 -- [Katie] [Baumgartner]

# %% [markdown]
# **TA Help:** N/A
#
# **Collaboration:** N/A
#
# **Internet Resources:** N/A
#
# **ChatGPT, Gemini, Claude, etc:** N/A

# %%
myDF <- read.csv('/anvil/projects/tdm/data/movies_and_tv/rotten_tomatoes_movies.csv')

# %%
dim(myDF)
# Out:
# [1] 16638    23

# %%
head(myDF)
# Out:
#   rotten_tomatoes_link
# 1 /m/0814255
# 2 /m/0878835
# 3 /m/10
# 4 /m/1000013-12_angry_men
# 5 /m/1000079-20000_leagues_under_the_sea
# 6 /m/10000_bc
#   movie_title
# 1 Percy Jackson & the Olympians: The Lightning Thief
# 2 Please Give
# 3 10
# 4 12 Angry Men (Twelve Angry Men)
# 5 20,000 Leagues Under The Sea
# 6 10,000 B.C.
#   movie_info
# 1 A teenager discovers he's the descendant of a Greek god and sets out on an adventure to settle an on-going battle between the gods.
# ...

# %%
tail(myDF)
# Out:
#       rotten_tomatoes_link movie_title
# 16633 /m/zoom_2006         Zoom
# 16634 /m/zoot_suit         Zoot Suit
# 16635 /m/zootopia          Zootopia
# 16636 /m/zorba_the_greek   Zorba the Greek
# 16637 /m/zulu              Zulu
# 16638 /m/zulu_dawn         Zulu Dawn
#       movie_info
# 16633 Former superhero Jack is called back to work to transform an unlikely group of ragtag kids into superheroes at a private Academy.
# 16634 Based on a 1940s Los Angeles murder trial, this film follows the case of members of a Mexican-American gang, led by Henry Reyna (Daniel Valdez), as they are tried and sentenced to San Quentin for a murder they may not have committed.
# ...

# %%
myDF <- myDF[ , !names(myDF) %in% c("cast", "movie_info")]

# %%
dim(myDF)
# Out:
# [1] 16638    21

# %%
head(myDF)
# Out:
#   rotten_tomatoes_link
# 1 /m/0814255
# 2 /m/0878835
# 3 /m/10
# 4 /m/1000013-12_angry_men
# 5 /m/1000079-20000_leagues_under_the_sea
# 6 /m/10000_bc
#   movie_title
# 1 Percy Jackson & the Olympians: The Lightning Thief
# 2 Please Give
# 3 10
# 4 12 Angry Men (Twelve Angry Men)
# 5 20,000 Leagues Under The Sea
# 6 10,000 B.C.
#   critics_consensus
# 1 Though it may seem like just another Harry Potter knockoff, Percy Jackson benefits from a strong supporting cast, a speedy plot, and plenty of fun with Greek mythology.
# 2 Nicole Holofcener's newest might seem slight in places, but its rendering of complex characters in a conflicted economic landscape is varied, natural, and touching all the same.
# 3
# 4 Sidney Lumet's feature debut is a superbly written, dramatically effective courtroom thriller that rightfully stands as a modern classic.
# ...

# %% [markdown]
# COLUMNS = rotten_tomatoes_link	movie_title	critics_consensus	poster_image_url	rating	genre	directors	writers	in_theaters_date	on_streaming_date	...	studio_name	tomatometer_status	tomatometer_rating	tomatometer_count	audience_status	audience_rating	audience_count	audience_top_critics_count	audience_fresh_critics_count	audience_rotten_critics_count
# DIMENSIONS = 16638*21

# %%
sort(table(myDF$rating))
# Out:
#     R) PG-13)   NC17      G     PG  PG-13     NR      R
#      1      3     37    652   2062   2885   4862   6136

# %%
plot(sort(table(myDF$rating)))
#plots the table
# Out:
# plot without title

# %% [markdown]
# ## Question 2

# %%
length(sort(table(myDF$rating)))
length(sort(table(myDF$directors)))
length(sort(table(myDF$studio_name)))

#returns the length of the columns
# Out:
# [1] 8
# [1] 8315
# [1] 2887

# %%
tail(sort(table(myDF$rating[myDF$rating != ""])))
# Out:
#  NC17     G    PG PG-13    NR     R
#    37   652  2062  2885  4862  6136

# %%
tail(sort(table(myDF$directors[myDF$directors != ""])))
# Out:
# Steven Soderbergh      Sidney Lumet  Steven Spielberg    Clint Eastwood
#                27                30                32                35
#  Alfred Hitchcock       Woody Allen
#                36                36

# %%
tail(sort(table(myDF$studio_name[myDF$studio_name != ""])))
# Out:
# Sony Pictures Home Entertainment                        IFC Films
#                              379                              398
#                 20th Century Fox               Universal Pictures
#                              414                              469
#            Warner Bros. Pictures               Paramount Pictures
#                              492                              497

# %% [markdown]
# Deliverables
# 2.2) Alfred Hitchcock and Woody Allen
# 2.3) Paramount Pictures

# %% [markdown]
# ## Question 3

# %%
head(myDF$genre)
# Out:
# [1] "Action & Adventure, Comedy, Drama, Science Fiction & Fantasy"
# [2] "Comedy"
# [3] "Comedy, Romance"
# [4] "Classics, Drama"
# [5] "Action & Adventure, Drama, Kids & Family"
# [6] "Action & Adventure, Classics, Drama"

# %%
head(myDF$genre == "Comedy") #first six of returned values of genre and comedy
# Out:
# [1] FALSE  TRUE FALSE FALSE FALSE FALSE

# %%
sum(myDF$genre == "Comedy") #how many of the first six are comedy(True)
# Out:
# [1] 1202

# %%
grep("Comedy", myDF$genre) #returns the index of any with comedy
# Out:
#    [1]     1     2     3     9    15    23    24    28    30    38    39    41
#   [13]    42    47    54    55    58    64    68    70    78    79    80    81
#   [25]    84    86    97   101   104   105   106   108   110   124   128   129
#   [37]   135   137   140   142   143   145   153   154   164   167   174   175
#   [49]   176   178   179   181   186   187   188   191   200   203   205   206
#   [61]   212   215   219   225   226   233   234   245   251   254   256   260
#   [73]   261   265   268   269   270   277   279   281   297   299   303   305
#   [85]   306   319   325   331   338   339   341   342   343   348   351   359
#   [97]   362   366   367   370   377   380   381   385   389   397   403   407
#  [109]   408   414   425   429   430   431   441   446   447   453   455   456
#  [121]   458   460   461   463   466   468   470   481   486   487   488   489
#  [133]   503   507   515   519   522   541   545   550   554   555   556   557
# ...

# %%
grepl("Comedy", myDF$genre) #returns true of any conatining comedy false otherwise
# Out:
#     [1]  TRUE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE
#    [13] FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE
#    [25] FALSE FALSE FALSE  TRUE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE
#    [37] FALSE  TRUE  TRUE FALSE  TRUE  TRUE FALSE FALSE FALSE FALSE  TRUE FALSE
#    [49] FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE FALSE FALSE  TRUE FALSE FALSE
#    [61] FALSE FALSE FALSE  TRUE FALSE FALSE FALSE  TRUE FALSE  TRUE FALSE FALSE
#    [73] FALSE FALSE FALSE FALSE FALSE  TRUE  TRUE  TRUE  TRUE FALSE FALSE  TRUE
#    [85] FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#    [97]  TRUE FALSE FALSE FALSE  TRUE FALSE FALSE  TRUE  TRUE  TRUE FALSE  TRUE
#   [109] FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [121] FALSE FALSE FALSE  TRUE FALSE FALSE FALSE  TRUE  TRUE FALSE FALSE FALSE
#   [133] FALSE FALSE  TRUE FALSE  TRUE FALSE FALSE  TRUE FALSE  TRUE  TRUE FALSE
# ...

# %%
sum(grepl("Comedy", myDF$genre)) #returns the sume of all the true values in grepl
# Out:
# [1] 5385

# %%
length(grep("Comedy", myDF$genre)) #Returns the length of the indexes of grep
# Out:
# [1] 5385

# %%
sort(table(myDF$genre[grepl("Comedy", myDF$genre) & (myDF$genre != "Comedy")]))
# Out:
#                             Action & Adventure, Animation, Art House & International, Comedy, Science Fiction & Fantasy
#                                                                                                                       1
#                                                          Action & Adventure, Animation, Classics, Comedy, Kids & Family
#                                                                                                                       1
#                               Action & Adventure, Animation, Classics, Comedy, Kids & Family, Musical & Performing Arts
#                                                                                                                       1
# Action & Adventure, Animation, Comedy, Cult Movies, Kids & Family, Musical & Performing Arts, Science Fiction & Fantasy
#                                                                                                                       1
# ...

# %%
length(myDF$genre[grepl("Comedy", myDF$genre) & (myDF$genre != "Comedy")])
# Out:
# [1] 4183

# %% [markdown]
# DELIVERABLES
# - used head so data is easier to read, remove head to get all instances
# 3.2) Comedy, Drama
# 3.3) Code below

# %%
sum(myDF$genre == "Romance") #exclusively romance
# Out:
# [1] 14

# %%
length(myDF$genre[grepl("Romance", myDF$genre) & (myDF$genre != "Romance")]) #contains multiple genres including romance
# Out:
# [1] 1793

# %%
sum(grepl("Romance", myDF$genre)) #all results that contain romance
# Out:
# [1] 1807

# %% [markdown]
# ## Question 4

# %%
myDF$rating[myDF$rating == "R)"] <- "R"
myDF$rating[myDF$rating == "PG-13)"] <- "PG-13"

# %%
table_data <- table(myDF$rating, myDF$tomatometer_status)

# %%
table_data
# Out:
#
#         Certified Fresh Fresh Rotten
#   G                 124   336    192
#   NC17                7    19     11
#   NR                576  3081   1205
#   PG                376   753    933
#   PG-13             563   593   1732
#   R                1311  1666   3160

# %%
plot(table_data)
# Out:
# Plot with title "table_data"

# %% [markdown]
# Markdown notes and full English sentences and analysis written here.

# %% [markdown]
# ## Question 5

# %%
paste(table_data)
# Out:
#  [1] "124"  "7"    "576"  "376"  "563"  "1311" "336"  "19"   "3081" "753"
# [11] "593"  "1666" "192"  "11"   "1205" "933"  "1732" "3160"

# %%
head(subset(myDF, rating=="PG" & tomatometer_status=="Certified Fresh"))
# Out:
#     rotten_tomatoes_link
# 21  /m/1000355-adventures_of_robin_hood
# 53  /m/1000626-all_about_eve
# 95  /m/10008507-deep_water
# 135 /m/10009001-the_freshman
# 308 /m/1002352-big_sleep
# 340 /m/1003318-butch_cassidy_and_the_sundance_kid
#     movie_title
# 21  The Adventures of Robin Hood
# 53  All About Eve
# 95  Deep Water
# 135 The Freshman
# 308 The Big Sleep
# 340 Butch Cassidy and the Sundance Kid
#     critics_consensus
# 21  Errol Flynn thrills as the legendary title character, and the film embodies the type of imaginative family adventure tailor-made for the silver screen.
# 53  Smart, sophisticated, and devastatingly funny, All About Eve is a Hollywood classic that only improves with age.
# 95  Equal parts mystery and biography, Deep Water is both an engrossing documentary and an affecting treatise on human folly and obsession.
# ...

# %%
subset(myDF, movie_title=="Arthur and the Invisibles (Arthur and the Minimoys)")
# Out:
#    rotten_tomatoes_link movie_title
# 33 /m/10004659-arthur   Arthur and the Invisibles (Arthur and the Minimoys)
#    critics_consensus
# 33 Arthur wastes its big-name voice talent on a predictable script and substandard CG animation.
#    poster_image_url
# 33 https://resizing.flixster.com/cwDm92aUYbGV8-DAKN_nNsJaxag=/206x305/v1.bTsxMTI5NjU2NztqOzE4MzEwOzEyMDA7MTUzNjsyMDQ4
#    rating genre                                               directors
# 33 PG     Animation, Kids & Family, Science Fiction & Fantasy Luc Besson
#    writers                   in_theaters_date on_streaming_date ... studio_name
# 33 Luc Besson, Celine Garcia 2007-01-12       2007-05-15        ... MGM
#    tomatometer_status tomatometer_rating tomatometer_count audience_status
# 33 Rotten             22                 91                Spilled
#    audience_rating audience_count audience_top_critics_count
# 33 56              134466         31
#    audience_fresh_critics_count audience_rotten_critics_count
# ...

# %%
subset(myDF, movie_title=="World War Z")
# Out:
#       rotten_tomatoes_link movie_title
# 16461 /m/world-war-z       World War Z
#       critics_consensus
# 16461 It's uneven and diverges from the source book, but World War Z still brings smart, fast-moving thrills and a solid performance from Brad Pitt to the zombie genre.
#       poster_image_url
# 16461 https://resizing.flixster.com/WX7ES-A6fj3FUGFYzUcG7RchUKA=/206x305/v1.bTsxMTE3MzAwMztqOzE4MzA5OzEyMDA7ODAwOzEyMDA
#       rating genre                                                 directors
# 16461 PG-13  Action & Adventure, Horror, Science Fiction & Fantasy Marc Forster
#       writers
# 16461 Matthew Michael Carnahan, J. Michael Straczynski, Damon Lindelof, Drew Goddard
#       in_theaters_date on_streaming_date ... studio_name
# 16461 2013-06-21       2013-09-17        ... Paramount Pictures
#       tomatometer_status tomatometer_rating tomatometer_count audience_status
# 16461 Fresh              66                 272               Upright
# ...

# %% [markdown]
# Deliverables
# 5.1) NR and Fresh

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
#
# https://www.purdue.edu/odos/osrr/honor-pledge/
